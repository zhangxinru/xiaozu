# %%
import numpy as np
import pandas as pd
import xgboost as xgb
from sklearn.feature_extraction import DictVectorizer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import Imputer,scale,normalize,MinMaxScaler
from pandas import Series,DataFrame 
import sklearn.preprocessing as preprocessing 
from sklearn import linear_model 
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestRegressor
#读取训练集
train = pd.read_csv('/Users/Administrator/Desktop/train.csv')
#读取测试集
test = pd.read_csv('/Users/Administrator/Desktop/test.csv')
#features选取
X_train = train[['Label','I1','I2','I3','I4','I5','I6','I7','I8','I9','I10','I11','I12','I13']]
X_test = test[['I1','I2','I3','I4','I5','I6','I7','I8','I9','I10','I11','I12','I13']]
 
y_train = train['Label']

X_train['I5'].fillna(X_train['I5'].mean(),inplace = True)
X_train['I6'].fillna(X_train['I6'].mean(),inplace = True)
X_train['I7'].fillna(X_train['I7'].mean(),inplace = True)
X_train['I8'].fillna(X_train['I8'].mean(),inplace = True)
X_train['I9'].fillna(X_train['I9'].mean(),inplace = True)
X_train['I11'].fillna(X_train['I11'].mean(),inplace = True) 
X_test['I5'].fillna(X_test['I5'].mean(),inplace = True)
X_test['I6'].fillna(X_test['I6'].mean(),inplace = True)
X_test['I7'].fillna(X_test['I7'].mean(),inplace = True)
X_test['I8'].fillna(X_test['I8'].mean(),inplace = True)
X_test['I9'].fillna(X_test['I9'].mean(),inplace = True)
X_test['I11'].fillna(X_test['I11'].mean(),inplace = True)
def set_missing_I1s(df): # 把已有的数值型特征取出来丢进Random Forest Regressor中 
    I1_df = df[['I1','I2','I5','I6','I7','I8','I9','I11']]  
    known_I1 = I1_df[I1_df.I1.notnull()].as_matrix() 
    unknown_I1 = I1_df[I1_df.I1.isnull()].as_matrix()
    # y即目标
    y = known_I1[:, 0] 
    # X即特征属性值 
    X = known_I1[:, 1:] 
    # fit到RandomForestRegressor之中 
    rfr = RandomForestRegressor(random_state=0, n_estimators=2000, n_jobs=-1) 
    rfr.fit(X, y) 
    # 用得到的模型进行未知结果预测 
    predictedI1s = rfr.predict(unknown_I1[:, 1::]) 
    # 用得到的预测结果填补原缺失数据 
    df.loc[ (df.I1.isnull()), 'I1' ] = predictedI1s 
    return df, rfr 
X_train ,rfr = set_missing_I1s(X_train)
tmp_df = X_test[['I1','I2','I5','I6','I7','I8','I9','I11']]
null_I1 = tmp_df[X_test.I1.isnull()].as_matrix() # 根据特征属性X预测并补上 
X = null_I1[:, 1:] 
predictedI1s = rfr.predict(X) 
X_test.loc[ (X_test.I1.isnull()), 'I1' ] = predictedI1s



 
def set_missing_I3s(df): # 把已有的数值型特征取出来丢进Random Forest Regressor中 
    I3_df = df[['I3','I2','I1','I5','I6','I7','I8','I9','I11']]  
    known_I3 = I3_df[I3_df.I3.notnull()].as_matrix() 
    unknown_I3 = I3_df[I3_df.I3.isnull()].as_matrix()
    # y即目标
    y = known_I3[:, 0] 
    # X即特征属性值 
    X = known_I3[:, 1:] 
    # fit到RandomForestRegressor之中 
    rfr = RandomForestRegressor(random_state=0, n_estimators=2000, n_jobs=-1) 
    rfr.fit(X, y) 
    # 用得到的模型进行未知结果预测 
    predictedI3s = rfr.predict(unknown_I3[:, 1::]) 
    # 用得到的预测结果填补原缺失数据 
    df.loc[ (df.I3.isnull()), 'I3' ] = predictedI3s 
    return df, rfr 
X_train ,rfr = set_missing_I3s(X_train)
tmp_df = X_test[['I3','I2','I1','I5','I6','I7','I8','I9','I11']] 
null_I3 = tmp_df[test.I3.isnull()].as_matrix() # 根据特征属性X预测并补上 
X = null_I3[:, 1:] 
predictedI3s = rfr.predict(X) 
X_test.loc[ (X_test.I3.isnull()), 'I3' ] = predictedI3s  
 
def set_missing_I4s(df): # 把已有的数值型特征取出来丢进Random Forest Regressor中 
    I4_df = df[['I4','I2','I3','I1','I5','I6','I7','I8','I9','I11']]  
    known_I4 = I4_df[I4_df.I4.notnull()].as_matrix() 
    unknown_I4 = I4_df[I4_df.I4.isnull()].as_matrix()
    # y即目标
    y = known_I4[:, 0] 
    # X即特征属性值 
    X = known_I4[:, 1:] 
    # fit到RandomForestRegressor之中 
    rfr = RandomForestRegressor(random_state=0, n_estimators=2000, n_jobs=-1) 
    rfr.fit(X, y) 
    # 用得到的模型进行未知结果预测 
    predictedI4s = rfr.predict(unknown_I4[:, 1::]) 
    # 用得到的预测结果填补原缺失数据 
    df.loc[ (df.I4.isnull()), 'I4' ] = predictedI4s 
    return df, rfr 
X_train ,rfr = set_missing_I4s(X_train)
tmp_df = X_test[['I4','I2','I3','I1','I5','I6','I7','I8','I9','I11']] 
null_I4 = tmp_df[X_test.I4.isnull()].as_matrix() # 根据特征属性X预测并补上 
X = null_I4[:, 1:] 
predictedI4s = rfr.predict(X) 
X_test.loc[ (X_test.I4.isnull()), 'I4' ] = predictedI4s 



def set_missing_I10s(df): # 把已有的数值型特征取出来丢进Random Forest Regressor中 
    I10_df = df[['I10','I2','I3','I4','I5','I6','I7','I8','I9','I1','I11']]  
    known_I10 = I10_df[I10_df.I10.notnull()].as_matrix() 
    unknown_I10 = I10_df[I10_df.I10.isnull()].as_matrix()
    # y即目标
    y = known_I10[:, 0] 
    # X即特征属性值 
    X = known_I10[:, 1:] 
    # fit到RandomForestRegressor之中 
    rfr = RandomForestRegressor(random_state=0, n_estimators=2000, n_jobs=-1) 
    rfr.fit(X, y) 
    # 用得到的模型进行未知结果预测 
    predictedI10s = rfr.predict(unknown_I10[:, 1::]) 
    # 用得到的预测结果填补原缺失数据 
    df.loc[ (df.I10.isnull()), 'I10' ] = predictedI10s 
    return df, rfr 
X_train ,rfr = set_missing_I10s(X_train)
tmp_df = X_test[['I10','I2','I3','I4','I5','I6','I7','I8','I9','I1','I11']] 
null_I10 = tmp_df[X_test.I10.isnull()].as_matrix() # 根据特征属性X预测并补上 
X = null_I10[:, 1:] 
predictedI10s = rfr.predict(X) 
X_test.loc[ (X_test.I10.isnull()), 'I10' ] = predictedI10s 

def set_missing_I12s(df): # 把已有的数值型特征取出来丢进Random Forest Regressor中 
    I12_df = df[['I12','I2','I3','I4','I5','I6','I7','I8','I9','I10','I11','I1']]  
    known_I12 = I12_df[I12_df.I12.notnull()].as_matrix() 
    unknown_I12 = I12_df[I12_df.I12.isnull()].as_matrix()
    # y即目标
    y = known_I12[:, 0] 
    # X即特征属性值 
    X = known_I12[:, 1:] 
    # fit到RandomForestRegressor之中 
    rfr = RandomForestRegressor(random_state=0, n_estimators=2000, n_jobs=-1) 
    rfr.fit(X, y) 
    # 用得到的模型进行未知结果预测 
    predictedI12s = rfr.predict(unknown_I12[:, 1::]) 
    # 用得到的预测结果填补原缺失数据 
    df.loc[ (df.I12.isnull()), 'I12' ] = predictedI12s 
    return df, rfr 
X_train ,rfr = set_missing_I12s(X_train)
tmp_df = X_test[['I12','I2','I3','I4','I5','I6','I7','I8','I9','I10','I11','I1']] 
null_I12 = tmp_df[X_test.I12.isnull()].as_matrix() # 根据特征属性X预测并补上 
X = null_I12[:, 1:] 
predictedI12s = rfr.predict(X) 
X_test.loc[ (X_test.I12.isnull()), 'I12' ] = predictedI12s 

def set_missing_I13s(df): # 把已有的数值型特征取出来丢进Random Forest Regressor中 
    I13_df = df[['I13','I2','I3','I4','I5','I6','I7','I8','I9','I10','I11','I12','I1']]  
    known_I13 = I13_df[I13_df.I13.notnull()].as_matrix() 
    unknown_I13 = I13_df[I13_df.I13.isnull()].as_matrix()
    # y即目标
    y = known_I13[:, 0] 
    # X即特征属性值 
    X = known_I13[:, 1:] 
    # fit到RandomForestRegressor之中 
    rfr = RandomForestRegressor(random_state=0, n_estimators=2000, n_jobs=-1) 
    rfr.fit(X, y) 
    # 用得到的模型进行未知结果预测 
    predictedI13s = rfr.predict(unknown_I13[:, 1::]) 
    # 用得到的预测结果填补原缺失数据 
    df.loc[ (df.I13.isnull()), 'I13' ] = predictedI13s 
    return df, rfr 
X_train ,rfr = set_missing_I13s(X_train)
tmp_df = X_test[['I13','I2','I3','I4','I5','I6','I7','I8','I9','I10','I11','I12','I1']] 
null_I13 = tmp_df[X_test.I13.isnull()].as_matrix() # 根据特征属性X预测并补上 
X = null_I13[:, 1:] 
predictedI13s = rfr.predict(X) 
X_test.loc[ (X_test.I13.isnull()), 'I13' ] = predictedI13s 
scaler = preprocessing.StandardScaler()
X_train['I1'] = scaler.fit_transform(X_train['I1'].values.reshape(-1,1))   
X_train['I2'] = scaler.fit_transform(X_train['I2'].values.reshape(-1,1))
X_train['I3'] = scaler.fit_transform(X_train['I3'].values.reshape(-1,1))
X_train['I4'] = scaler.fit_transform(X_train['I4'].values.reshape(-1,1))
X_train['I5'] = scaler.fit_transform(X_train['I5'].values.reshape(-1,1))
X_train['I6'] = scaler.fit_transform(X_train['I6'].values.reshape(-1,1))
X_train['I7'] = scaler.fit_transform(X_train['I7'].values.reshape(-1,1))
X_train['I8'] = scaler.fit_transform(X_train['I8'].values.reshape(-1,1))
X_train['I9'] = scaler.fit_transform(X_train['I9'].values.reshape(-1,1))
X_train['I10'] = scaler.fit_transform(X_train['I10'].values.reshape(-1,1))
X_train['I11'] = scaler.fit_transform(X_train['I11'].values.reshape(-1,1))
X_train['I12'] = scaler.fit_transform(X_train['I12'].values.reshape(-1,1))
X_train['I13'] = scaler.fit_transform(X_train['I13'].values.reshape(-1,1))
X_test['I1'] = scaler.fit_transform(X_test['I1'].values.reshape(-1,1))   
X_test['I2'] = scaler.fit_transform(X_test['I2'].values.reshape(-1,1))
X_test['I3'] = scaler.fit_transform(X_test['I3'].values.reshape(-1,1))
X_test['I4'] = scaler.fit_transform(X_test['I4'].values.reshape(-1,1))
X_test['I5'] = scaler.fit_transform(X_test['I5'].values.reshape(-1,1))
X_test['I6'] = scaler.fit_transform(X_test['I6'].values.reshape(-1,1))
X_test['I7'] = scaler.fit_transform(X_test['I7'].values.reshape(-1,1))
X_test['I8'] = scaler.fit_transform(X_test['I8'].values.reshape(-1,1))
X_test['I9'] = scaler.fit_transform(X_test['I9'].values.reshape(-1,1))
X_test['I10'] = scaler.fit_transform(X_test['I10'].values.reshape(-1,1))
X_test['I11'] = scaler.fit_transform(X_test['I11'].values.reshape(-1,1))
X_test['I12'] = scaler.fit_transform(X_test['I12'].values.reshape(-1,1))
X_test['I13'] = scaler.fit_transform(X_test['I13'].values.reshape(-1,1))
X_train.to_csv('/Users/Administrator/Desktop/train4.csv', index=False)
X_test.to_csv('/Users/Administrator/Desktop/test4.csv', index=False)
# Out:
# C:\Users\Administrator\Anaconda3\lib\site-packages\pandas\core\generic.py:5434: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
# C:\Users\Administrator\Anaconda3\lib\site-packages\ipykernel_launcher.py:42: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
# C:\Users\Administrator\Anaconda3\lib\site-packages\ipykernel_launcher.py:43: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
# C:\Users\Administrator\Anaconda3\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...
